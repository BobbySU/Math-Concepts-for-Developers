# %%
import pandas as pd

df = pd.read_csv(
    "Segmentation_Summer Seasonal.dat",
    sep="\t",
    encoding="cp1251"
)

df.head()
# Out:
#    Customer           City Channel                   Segment  Urbanicity  \
# 0     10000  ЗЛАТНИ ПЯСЪЦИ  Hotels     Seasonal High Traffic           3
# 1     10001   СЛЪНЧЕВ БРЯГ     Qsr     Seasonal High Traffic           1
# 2     10002   СЛЪНЧЕВ БРЯГ     Qsr     Seasonal High Traffic           1
# 3     10003   СЛЪНЧЕВ БРЯГ     Qsr  Seasonal Low/Mid Traffic           1
# 4     10004   СЛЪНЧЕВ БРЯГ     Qsr     Seasonal High Traffic           1
#
#     Traffic Traffic Index Equipment (Y/N) # of doors Sales 2025 CS
# 0  30422,86          High             Yes          6             0
# 1  58764,25          High             Yes          0             0
# 2   32763,5          High             Yes          0             0
# 3   23147,5        Medium             Yes          0             0
# 4  34339,25          High             Yes          2            56
